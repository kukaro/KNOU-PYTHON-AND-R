# %%
health <- read.csv('../data/health.csv', header=T)
health
# Out:
#    id weight pulse muscle quarter time
# 1   1 217    67    260    91      481
# 2   2 141    52    190    66      292
# 3   3 152    58    203    68      338
# 4   4 153    56    183    70      357
# 5   5 180    66    170    77      396
# 6   6 193    71    178    82      429
# 7   7 162    65    160    74      345
# 8   8 180    80    170    84      469
# 9   9 205    77    188    83      425
# 10 10 168    74    170    79      358
# 11 11 232    65    220    72      393
# 12 12 146    68    158    68      346
# 13 13 173    51    243    56      279
# 14 14 155    64    198    59      311
# 15 15 212    66    220    77      401
# 16 16 138    70    180    62      267
# 17 17 147    54    150    75      404
# 18 18 197    76    228    88      442
# 19 19 165    59    188    70      368
# 20 20 125    58    160    66      295
# 21 21 161    52    190    69      391
# 22 22 132    62    163    59      264
# 23 23 257    64    313    96      487
# 24 24 236    72    225    84      481
# 25 25 149    57    173    68      374
# 26 26 161    57    173    65      309
# 27 27 198    59    220    62      367
# 28 28 245    70    218    69      469
# 29 29 141    63    193    60      252
# 30 30 177    53    183    75      338

# %%
plot(health$weight, health$time, pch=19)
# Out:
# plot without title

# %%
pairs(health[,-1],pch=19)
# Out:
# plot without title

# %%
cor(health[,-1])
# Out:
#         weight    pulse      muscle     quarter   time
# weight  1.0000000 0.41992379 0.73655862 0.6431189 0.7980913
# pulse   0.4199238 1.00000000 0.06033638 0.5388523 0.5011203
# muscle  0.7365586 0.06033638 1.00000000 0.4001311 0.4446888
# quarter 0.6431189 0.53885228 0.40013111 1.0000000 0.8480748
# time    0.7980913 0.50112029 0.44468884 0.8480748 1.0000000

# %%
x <- health[,c(2:5)]
x
# Out:
#    weight pulse muscle quarter
# 1  217    67    260    91
# 2  141    52    190    66
# 3  152    58    203    68
# 4  153    56    183    70
# 5  180    66    170    77
# 6  193    71    178    82
# 7  162    65    160    74
# 8  180    80    170    84
# 9  205    77    188    83
# 10 168    74    170    79
# 11 232    65    220    72
# 12 146    68    158    68
# 13 173    51    243    56
# 14 155    64    198    59
# 15 212    66    220    77
# 16 138    70    180    62
# 17 147    54    150    75
# 18 197    76    228    88
# 19 165    59    188    70
# 20 125    58    160    66
# 21 161    52    190    69
# 22 132    62    163    59
# 23 257    64    313    96
# 24 236    72    225    84
# 25 149    57    173    68
# 26 161    57    173    65
# 27 198    59    220    62
# 28 245    70    218    69
# 29 141    63    193    60
# 30 177    53    183    75

# %%
cor(x, health$time)
# Out:
#         [,1]
# weight  0.7980913
# pulse   0.5011203
# muscle  0.4446888
# quarter 0.8480748

# %%
cor.test(health$weight, health$time)
# Out:
# 	Pearson's product-moment correlation
#
# data:  health$weight and health$time
# t = 7.0089, df = 28, p-value = 1.271e-07
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.6145110 0.8996781
# sample estimates:
#       cor
# 0.7980913
